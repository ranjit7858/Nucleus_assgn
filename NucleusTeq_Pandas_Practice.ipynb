# %%
import pandas as pd

# %%
df1 = pd.read_csv('greek_god.csv',sep = ',')

# %%
df1
# Out:
#         God                 Domain      Symbol    Age
# 0      Zeus       King of the Gods  Thundebolt  10000
# 1  Poseidon         God of the Sea     Trident   9000
# 2      Hera      Queen of the Gods     Peacock   8500
# 3    Athena      Goddess of Wisdom         Owl   8000
# 4     Hades  God of the Underworld      Helmet   9500

# %%
df2 = pd.read_csv('greek_goddesses.csv',sep = ',')

# %%
df2
# Out:
#       Goddess                   Domain         Symbol   Age
# 0   Aphrodite          Goddess of Love           Dove  7000
# 1     Artemis          Goddess of Hunt  Bow and Arrow  7500
# 2     Demeter   Goddess of Agriculture          Wheat  8000
# 3      Hestia         Goddess of Earth           Fire  8200
# 4  Persephone  Queen of the Underworld    Pomegranate  7800

# %%
df1_changed = df1
# df1_changed['God'] = df1_changed['God/Goddess']
df1_changed.columns.values[3] = 'God/Goddess'

# %%
df1_changed

# %%
#Question 1 Merge the Data
df_new = pd.merge(df1,df2,how = 'outer')

# %%
df_new
# Out:
#   God/Goddess                   Domain         Symbol    Age
# 0        Zeus         King of the Gods     Thundebolt  10000
# 1    Poseidon           God of the Sea        Trident   9000
# 2        Hera        Queen of the Gods        Peacock   8500
# 3      Athena        Goddess of Wisdom            Owl   8000
# 4       Hades    God of the Underworld         Helmet   9500
# 5   Aphrodite          Goddess of Love           Dove   7000
# 6     Artemis          Goddess of Hunt  Bow and Arrow   7500
# 7     Demeter   Goddess of Agriculture          Wheat   8000
# 8      Hestia         Goddess of Earth           Fire   8200
# 9  Persephone  Queen of the Underworld    Pomegranate   7800

# %%
ans2 = df_new[df_new['Age']>8000].sort_values(by='Age',ascending = True)

# %%
ans2
# Out:
#   God/Goddess                 Domain      Symbol    Age
# 8      Hestia       Goddess of Earth        Fire   8200
# 2        Hera      Queen of the Gods     Peacock   8500
# 1    Poseidon         God of the Sea     Trident   9000
# 4       Hades  God of the Underworld      Helmet   9500
# 0        Zeus       King of the Gods  Thundebolt  10000

# %%
df_2 = pd.merge(df1,df2,how = 'inner',on='Domain')

# %%
df_2
# Out:
# Empty DataFrame
# Columns: [God/Goddess_x, Domain, Symbol_x, Age_x, God/Goddess_y, Symbol_y, Age_y]
# Index: []

# %%
ans4 = df_new.max(df_new['Age'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-f3f1c6927a8b> in <cell line: 1>()
# ----> 1 ans4 = df_new.max(df_new['Age'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   11939             **kwargs,
#   11940         ):
# > 11941             return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11942
#   11943         setattr(cls, "max", max)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   11381         **kwargs,
#   11382     ):
# > 11383         return self._stat_function(
#   11384             "max",
#   11385             nanops.nanmax,
#
# ...

# %%
df_new.max()
# Out:
#   File "<ipython-input-13-5de9a672f9fc>", line 1
#     df_new.max().
#                  ^
# SyntaxError: invalid syntax

# %%
#Ans 5

import numpy as np

df1['Age Group'] = np.where(df1['Age']<5000, 'Young',
                   np.where(df1["Age"]<8000, 'Middle Aged','Old', ))

df2['Age Group'] = np.where(df2['Age']<5000, 'Young',
                   np.where(df2["Age"]<8000, 'Middle Aged','Old', ))

df1,df2
# Out:
# (  God/Goddess                 Domain      Symbol    Age Age Group
#  0        Zeus       King of the Gods  Thundebolt  10000       Old
#  1    Poseidon         God of the Sea     Trident   9000       Old
#  2        Hera      Queen of the Gods     Peacock   8500       Old
#  3      Athena      Goddess of Wisdom         Owl   8000       Old
#  4       Hades  God of the Underworld      Helmet   9500       Old,
#    God/Goddess                   Domain         Symbol   Age    Age Group
#  0   Aphrodite          Goddess of Love           Dove  7000  Middle Aged
#  1     Artemis          Goddess of Hunt  Bow and Arrow  7500  Middle Aged
#  2     Demeter   Goddess of Agriculture          Wheat  8000          Old
#  3      Hestia         Goddess of Earth           Fire  8200          Old
#  4  Persephone  Queen of the Underworld    Pomegranate  7800  Middle Aged)

# %%
# def age_category(df):
#   if df['Age']<:
#     val = "Young"

#   elif df["Age"]>5000 and df["Age"]<8000:
#     val = "Middle Aged"
#   elif df["Age"]>8000:
#     val = "Old"
# df_new["Age_Group"]= df_new.apply(age_category,axis=1)

# %%
#Ans 6

age_diff = abs(df1['Age'].mean() - df2['Age'].mean())
print("Avg age of God ",df1['Age'].mean(),"\nAvg age of Goddess ", df2['Age'].mean())
print(age_diff)

if df1['Age'].mean()>df2['Age'].mean():
  print("Gods group is older")
else:
  print("Goddesses group is older")
# Out:
# Avg age of God  9000.0
# Avg age of Goddess  7700.0
# 1300.0
# Gods group is older

# %%
# Out:
# 1300.0

# %%
df_new
# Out:
#   God/Goddess                   Domain         Symbol    Age    Age Group
# 0        Zeus         King of the Gods     Thundebolt  10000          Old
# 1    Poseidon           God of the Sea        Trident   9000          Old
# 2        Hera        Queen of the Gods        Peacock   8500          Old
# 3      Athena        Goddess of Wisdom            Owl   8000          Old
# 4       Hades    God of the Underworld         Helmet   9500          Old
# 5   Aphrodite          Goddess of Love           Dove   7000  Middle Aged
# 6     Artemis          Goddess of Hunt  Bow and Arrow   7500  Middle Aged
# 7     Demeter   Goddess of Agriculture          Wheat   8000          Old
# 8      Hestia         Goddess of Earth           Fire   8200          Old
# 9  Persephone  Queen of the Underworld    Pomegranate   7800  Middle Aged

# %%
#Ans 7
for index, row in df_new.iterrows():
    if row['Age'] > 8000:
        print(row['God/Goddess'], 'is over 8000')
# Out:
# Zeus is over 8000
# Poseidon is over 8000
# Hera is over 8000
# Hades is over 8000
# Hestia is over 8000
